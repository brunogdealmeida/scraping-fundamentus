# %%
import json
import pandas as pd
import re
import time
import requests as rq
from bs4 import BeautifulSoup

# %%
with open("tickers.txt", "r") as fundamentus_file:
    stocks = fundamentus_file.read().split()
    dict_data = {}

for stock in stocks:
    time.sleep(20)
    stock_url = 'https://www.fundamentus.com.br/detalhes.php?papel={}'.format(stock)

    print(stock_url)
    headers = {"User-Agent":"Mozilla/5.0"}
    page = rq.get(stock_url, headers=headers)
    html = BeautifulSoup(page.text, 'html.parser')
    #print(html)

    #tables = html.select('table.w728')
    #print(tables)
    names = html.find_all('td', class_='label')
    help_tips = html.find_all('span', class_='help tips')
    help_tips2 = html.find_all('span', class_='title')
    data = html.find_all('td', class_='data')

    if len(data) == 59:
        #Campo Papel
        #field_papel = names[0].get_text().replace('\n          ','')
        value_papel = data[0].get_text().replace('\n          ','')
        #help_papel = help_tips[0].get_attribute_list('title')
        #Campo Última Cotação
        #field_cotacao = names[1].get_text()
        value_cotacao = data[1].get_text().replace('\n          ','')
        #help_cotacao = help_tips[1].get_attribute_list('title')
        #Campo Tipo da ação (ON, PN)
        #field_tipoacao = names[2].get_text()
        value_tipoacao = data[2].get_text().replace('\n          ','')
        #help_tipoacao = help_tips[2].get_attribute_list('title')
        #Data Ultima Cotação 
        #field_datacotacao = names[3].get_text()
        value_datacotacao = data[3].get_text().replace('\n          ','')
        #help_datacotacao = help_tips[3].get_attribute_list('title')
        #Campo Nome Comercial da Empresa
        #field_nomeempresa = names[4].get_text()
        value_nomeempresa = data[4].get_text().replace('\n          ','')
        #help_nomeempresa = help_tips[4].get_attribute_list('title')
        #Campo Menor Cotação nos ultimos 12 meses
        #field_min52sem = names[5].get_text()
        value_min52sem = data[5].get_text().replace('\n          ','')
        #help_min52sem = help_tips[5].get_attribute_list('title')
        #Campo Setor de Atuação
        #field_setor = names[6].get_text()
        value_setor = data[6].get_text().replace('\n          ','')
        #help_setor = help_tips[6].get_attribute_list('title')
        #Campo Máxima 52 semanas
        #field_max52sem = names[7].get_text()
        value_max52sem = data[7].get_text().replace('\n          ','')
        #help_max52sem = help_tips[7].get_attribute_list('title')
        #Campo SubSetor
        #field_subsetor = names[8].get_text()
        value_subsetor = data[8].get_text().replace('\n          ','')
        #help_subsetor = help_tips[8].get_attribute_list('title')
        #Campo Volume média de Negociação dos ultimos 2 meses
        #field_volmedio2m = names[9].get_text()
        value_volmedio2m = data[9].get_text().replace('\n          ','')
        #help_volmedio2m = help_tips[9].get_attribute_list('title')
        #Campo Valor de Mercado
        #field_valormercado = names[10].get_text()
        value_valormercado = data[10].get_text().replace('\n          ','')
        #help_valormercado = help_tips[10].get_attribute_list('title')
        #Campo Ultimo Balanço Processado
        #field_ultimobalanco = names[11].get_text()
        value_ultimobalanco = data[11].get_text().replace('\n          ','')
        #help_ultimobalanco = help_tips[11].get_attribute_list('title')
        #Campo Valor da Firma - Valor de Mercado + Divida Líquida
        #field_valorfirma = names[12].get_text()
        value_valorfirma = data[12].get_text().replace('\n          ','')
        #help_valorfirma = help_tips[12].get_attribute_list('title')
        #Campo Numero de Ações
        #field_numeroacoes = names[13].get_text()
        value_numeroacoes = data[13].get_text().replace('\n          ','')
        #help_numeroacoes = help_tips[13].get_attribute_list('title')
        #Campo Oscilação no Dia
        #field_oscilacaodia = names[14].get_text()
        value_oscilacaodia = data[14].get_text().replace('\n          ','')
        #help_oscilacaodia = help_tips[14].get_attribute_list('title')
        #Campo P/L
        #field_pl = names[15].get_text()
        value_pl = data[15].get_text().replace('\n          ','')
        #help_pl = help_tips[15].get_attribute_list('title')
        #Campo PLA
        #field_pla = names[16].get_text()
        value_pla = data[16].get_text().replace('\n          ','')
        #help_pla = help_tips[16].get_attribute_list('title')
        #Campo Oscilação no Mês
        #field_oscilacaomes = names[17].get_text()
        value_oscilacaomes = data[17].get_text().replace('\n          ','')
        #help_oscilacaomes = help_tips[17].get_attribute_list('title')
        #Campo P/VP
        #field_pvp = names[18].get_text()
        value_pvp = data[18].get_text().replace('\n          ','')
        #help_pvp = help_tips[18].get_attribute_list('title')
        #Campo VPA
        #field_vpa = names[19].get_text()
        value_vpa = data[19].get_text().replace('\n          ','')
        #help_vpa = help_tips[19].get_attribute_list('title')
        #Campo Oscilação 30 dias
        #field_oscilacao30dias = names[20].get_text()
        value_oscilacao30dias = data[20].get_text().replace('\n          ','')
        #help_oscilacao30dias = help_tips[20].get_attribute_list('title')
        #Campo P/EBIT
        #field_pebit = names[21].get_text()
        value_pebit = data[21].get_text().replace('\n          ','')
        #help_pebit = help_tips[21].get_attribute_list('title')
        #Campo Margem Bruta
        #field_margembruta = names[22].get_text()
        value_margembruta = data[22].get_text().replace('\n          ','')
        #help_margembruta = help_tips[22].get_attribute_list('title')
        #Campo Oscilação 12 meses
        #field_oscilacao12meses = names[23].get_text()
        value_oscilacao12meses = data[23].get_text().replace('\n          ','')
        #help_oscilacao12meses = help_tips[23].get_attribute_list('title')
        #Campo PSR
        #field_psr = names[24].get_text()
        value_psr = data[24].get_text().replace('\n          ','')
        #help_psr = help_tips[24].get_attribute_list('title')
        #Campo Margem EBIT
        #field_margemebit = names[25].get_text()
        value_margemebit = data[25].get_text().replace('\n          ','')
        #help_margemebit = help_tips[25].get_attribute_list('title')
        #Campo Oscilação 2020
        #field_oscilacao2020 = names[26].get_text()
        value_oscilacao2020 = data[26].get_text().replace('\n          ','')
        #help_oscilacao2020 = help_tips[26].get_attribute_list('title')
        #Campo P/Ativos
        #field_pativos = names[27].get_text()
        value_pativos = data[27].get_text().replace('\n          ','')
        #help_pativos = help_tips[27].get_attribute_list('title')
        #Campo Margem Líquida
        #field_margemliquida = names[28].get_text()
        value_margemliquida = data[28].get_text().replace('\n          ','')
        #help_margemliquida = help_tips[28].get_attribute_list('title')
        #Campo Oscilação 2019
        #field_oscilacao2019 = names[29].get_text()
        value_oscilacao2019 = data[29].get_text().replace('\n          ','')
        #help_oscilacao2019 = help_tips[29].get_attribute_list('title')
        #Campo P/ Capital de Giro
        #field_pcapitalgiro = names[30].get_text()
        value_pcapitalgiro = data[30].get_text().replace('\n          ','')
        #help_pcapitalgiro = help_tips[30].get_attribute_list('title')
        #Campo EBIT/Ativo
        #field_ebitativo = names[31].get_text()
        value_ebitativo = data[31].get_text().replace('\n          ','')
        #help_ebitativo = help_tips[31].get_attribute_list('title')
        #Campo Oscilação 2018
        #field_oscilacao2018 = names[32].get_text()
        value_oscilacao2018 = data[32].get_text().replace('\n          ','')
        #help_oscilacao2018 = help_tips[32].get_attribute_list('title')
        #Campo P/Ativ Circulante Líquido
        #field_pativcircliq = names[33].get_text()
        value_pativcircliq = data[33].get_text().replace('\n          ','')
        #help_pativcircliq = help_tips[33].get_attribute_list('title')
        #Campo ROIC
        #field_roic = names[34].get_text()
        value_roic = data[34].get_text().replace('\n          ','')
        #help_roic = help_tips[34].get_attribute_list('title')
        #Campo Oscilação 2017
        #field_oscilacao2017 = names[35].get_text()
        value_oscilacao2017 = data[35].get_text().replace('\n          ','')
        #help_oscilacao2017 = help_tips[35].get_attribute_list('title')
        #Campo Dividend Yield
        #field_divyield = names[36].get_text()
        value_divyield = data[36].get_text().replace('\n          ','')
        #help_divyield = help_tips[36].get_attribute_list('title')
        #Campo ROE
        #field_roe = names[37].get_text()
        value_roe = data[37].get_text().replace('\n          ','')
        #help_roe = help_tips[37].get_attribute_list('title')
        #Campo Oscilação 2016
        #field_oscilacao2016 = names[38].get_text()
        value_oscilacao2016 = data[38].get_text().replace('\n          ','')
        #help_oscilacao2016 = help_tips[38].get_attribute_list('title')
        #Campo EV/EBITDA
        #field_evebitda = names[39].get_text()
        value_evebitda = data[39].get_text().replace('\n          ','')
        #help_evebitda = help_tips[39].get_attribute_list('title')
        #Campo Liquidez Corrente
        #field_liquidezcorrente = names[40].get_text()
        value_liquidezcorrente = data[40].get_text().replace('\n          ','')
        #help_liquidezcorrente = help_tips[40].get_attribute_list('title')
        #Campo Oscilação 2015
        #field_oscilacao2015 = names[41].get_text()
        value_oscilacao2015 = data[41].get_text().replace('\n          ','')
        #help_oscilacao2015 = help_tips[41].get_attribute_list('title')
        #Campo EV/EBIT
        #field_evebit = names[42].get_text()
        value_evebit = data[42].get_text().replace('\n          ','')
        #help_evebit = help_tips[42].get_attribute_list('title')
        #Campo Divida Bruta / Patrimonio
        #field_divbrpatrim = names[43].get_text()
        value_divbrpatrim = data[43].get_text().replace('\n          ','')
        #help_divbrpatrim = help_tips[43].get_attribute_list('title')
        #Campo 44 não contém nada
        #Campo Crescimento Receita 5 anos
        #field_crescrec5a = names[45].get_text()
        value_crescrec5a = data[45].get_text().replace('\n          ','')
        #help_crescrec5a = help_tips[45].get_attribute_list('title')
        #Campo Giro Ativos
        #field_giroativos = names[46].get_text()
        value_giroativos = data[46].get_text().replace('\n          ','')
        #help_giroativos = help_tips[46].get_attribute_list('title')
        #Campo Ativo
        #field_ativo = names[47].get_text()
        value_ativo = data[47].get_text().replace('\n          ','')
        #help_ativo = help_tips[47].get_attribute_list('title')
        #Campo Dívida Bruta
        #field_divbruta = names[48].get_text()
        value_divbruta = data[48].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Disponibilidades
        #field_disponibilidades = names[49].get_text()
        value_disponibilidades = data[49].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Dívida Líquida
        #field_divliquida = names[50].get_text()
        value_divliquida = data[50].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Ativo Circulante
        #field_ativocirculante = names[51].get_text()
        value_ativocirculante = data[51].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo PATRIMONIO LIQUIDO
        #field_patrimliq = names[52].get_text()
        value_patrimliq = data[52].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Receita Líquida 12 meses
        #field_receitaliquida12m = names[53].get_text()
        value_receitaliquida12m = data[53].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Receita Líquida 3 meses
        #field_receitaliquida3m = names[54].get_text()
        value_receitaliquida3m = data[54].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo EBIT 12 meses
        #field_ebit12meses = names[55].get_text()
        value_ebit12meses = data[55].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo EBIT 3 meses
        #field_ebit3meses = names[56].get_text()
        value_ebit3meses = data[56].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Lucro Liquido 12 meses
        #field_lucroliquido12m = names[57].get_text()
        value_lucroliquido12m = data[57].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Lucro Liquido 3 meses
        #field_lucroliquido3m = names[58].get_text()
        value_lucroliquido3m = data[58].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #print(value_evebitda)
        # Campos que pertencem a outra categoria
        value_depositos = 0
        value_cartdecredito = 0

        dict_data = {stock:[value_papel, value_cotacao, value_tipoacao, value_datacotacao, value_nomeempresa, value_min52sem, value_setor, value_max52sem, value_subsetor, value_volmedio2m, value_valormercado,value_ultimobalanco, value_valorfirma, value_numeroacoes, value_oscilacaodia, value_pl,value_pla,value_oscilacaomes, value_pvp, value_vpa, value_oscilacao30dias, value_pebit,value_margembruta, value_oscilacao12meses, value_psr,value_margemebit, value_oscilacao2020,value_pativos, value_margemliquida, value_oscilacao2019, value_pcapitalgiro, value_ebitativo,value_oscilacao2018, value_pativcircliq, value_roic, value_oscilacao2017, value_divyield,value_roe, value_oscilacao2016, value_evebitda, value_liquidezcorrente, value_oscilacao2015,value_evebit, value_divbrpatrim, value_crescrec5a, value_giroativos, value_ativo, value_depositos,value_cartdecredito, value_patrimliq, value_disponibilidades, value_divliquida, value_ativocirculante, value_receitaliquida12m, value_receitaliquida3m, value_ebit12meses, value_ebit3meses,value_lucroliquido12m, value_lucroliquido3m]
                    }

    elif len(data) == 57:
        #Campo Papel
        #field_papel = names[0].get_text().replace('\n          ','')
        value_papel = data[0].get_text().replace('\n          ','')
        #help_papel = help_tips[0].get_attribute_list('title')
        #Campo Última Cotação
        #field_cotacao = names[1].get_text()
        value_cotacao = data[1].get_text().replace('\n          ','')
        #help_cotacao = help_tips[1].get_attribute_list('title')
        #Campo Tipo da ação (ON, PN)
        #field_tipoacao = names[2].get_text()
        value_tipoacao = data[2].get_text().replace('\n          ','')
        #help_tipoacao = help_tips[2].get_attribute_list('title')
        #Data Ultima Cotação 
        #field_datacotacao = names[3].get_text()
        value_datacotacao = data[3].get_text().replace('\n          ','')
        #help_datacotacao = help_tips[3].get_attribute_list('title')
        #Campo Nome Comercial da Empresa
        #field_nomeempresa = names[4].get_text()
        value_nomeempresa = data[4].get_text().replace('\n          ','')
        #help_nomeempresa = help_tips[4].get_attribute_list('title')
        #Campo Menor Cotação nos ultimos 12 meses
        #field_min52sem = names[5].get_text()
        value_min52sem = data[5].get_text().replace('\n          ','')
        #help_min52sem = help_tips[5].get_attribute_list('title')
        #Campo Setor de Atuação
        #field_setor = names[6].get_text()
        value_setor = data[6].get_text().replace('\n          ','')
        #help_setor = help_tips[6].get_attribute_list('title')
        #Campo Máxima 52 semanas
        #field_max52sem = names[7].get_text()
        value_max52sem = data[7].get_text().replace('\n          ','')
        #help_max52sem = help_tips[7].get_attribute_list('title')
        #Campo SubSetor
        #field_subsetor = names[8].get_text()
        value_subsetor = data[8].get_text().replace('\n          ','')
        #help_subsetor = help_tips[8].get_attribute_list('title')
        #Campo Volume média de Negociação dos ultimos 2 meses
        #field_volmedio2m = names[9].get_text()
        value_volmedio2m = data[9].get_text().replace('\n          ','')
        #help_volmedio2m = help_tips[9].get_attribute_list('title')
        #Campo Valor de Mercado
        #field_valormercado = names[10].get_text()
        value_valormercado = data[10].get_text().replace('\n          ','')
        #help_valormercado = help_tips[10].get_attribute_list('title')
        #Campo Ultimo Balanço Processado
        #field_ultimobalanco = names[11].get_text()
        value_ultimobalanco = data[11].get_text().replace('\n          ','')
        #help_ultimobalanco = help_tips[11].get_attribute_list('title')
        #Campo Valor da Firma - Valor de Mercado + Divida Líquida
        #field_valorfirma = names[12].get_text()
        value_valorfirma = data[12].get_text().replace('\n          ','')
        #help_valorfirma = help_tips[12].get_attribute_list('title')
        #Campo Numero de Ações
        #field_numeroacoes = names[13].get_text()
        value_numeroacoes = data[13].get_text().replace('\n          ','')
        #help_numeroacoes = help_tips[13].get_attribute_list('title')
        #Campo Oscilação no Dia
        #field_oscilacaodia = names[14].get_text()
        value_oscilacaodia = data[14].get_text().replace('\n          ','')
        #help_oscilacaodia = help_tips[14].get_attribute_list('title')
        #Campo P/L
        #field_pl = names[15].get_text()
        value_pl = data[15].get_text().replace('\n          ','')
        #help_pl = help_tips[15].get_attribute_list('title')
        #Campo PLA
        #field_pla = names[16].get_text()
        value_pla = data[16].get_text().replace('\n          ','')
        #help_pla = help_tips[16].get_attribute_list('title')
        #Campo Oscilação no Mês
        #field_oscilacaomes = names[17].get_text()
        value_oscilacaomes = data[17].get_text().replace('\n          ','')
        #help_oscilacaomes = help_tips[17].get_attribute_list('title')
        #Campo P/VP
        #field_pvp = names[18].get_text()
        value_pvp = data[18].get_text().replace('\n          ','')
        #help_pvp = help_tips[18].get_attribute_list('title')
        #Campo VPA
        #field_vpa = names[19].get_text()
        value_vpa = data[19].get_text().replace('\n          ','')
        #help_vpa = help_tips[19].get_attribute_list('title')
        #Campo Oscilação 30 dias
        #field_oscilacao30dias = names[20].get_text()
        value_oscilacao30dias = data[20].get_text().replace('\n          ','')
        #help_oscilacao30dias = help_tips[20].get_attribute_list('title')
        #Campo P/EBIT
        #field_pebit = names[21].get_text()
        value_pebit = data[21].get_text().replace('\n          ','')
        #help_pebit = help_tips[21].get_attribute_list('title')
        #Campo Margem Bruta
        #field_margembruta = names[22].get_text()
        value_margembruta = data[22].get_text().replace('\n          ','')
        #help_margembruta = help_tips[22].get_attribute_list('title')
        #Campo Oscilação 12 meses
        #field_oscilacao12meses = names[23].get_text()
        value_oscilacao12meses = data[23].get_text().replace('\n          ','')
        #help_oscilacao12meses = help_tips[23].get_attribute_list('title')
        #Campo PSR
        #field_psr = names[24].get_text()
        value_psr = data[24].get_text().replace('\n          ','')
        #help_psr = help_tips[24].get_attribute_list('title')
        #Campo Margem EBIT
        #field_margemebit = names[25].get_text()
        value_margemebit = data[25].get_text().replace('\n          ','')
        #help_margemebit = help_tips[25].get_attribute_list('title')
        #Campo Oscilação 2020
        #field_oscilacao2020 = names[26].get_text()
        value_oscilacao2020 = data[26].get_text().replace('\n          ','')
        #help_oscilacao2020 = help_tips[26].get_attribute_list('title')
        #Campo P/Ativos
        #field_pativos = names[27].get_text()
        value_pativos = data[27].get_text().replace('\n          ','')
        #help_pativos = help_tips[27].get_attribute_list('title')
        #Campo Margem Líquida
        #field_margemliquida = names[28].get_text()
        value_margemliquida = data[28].get_text().replace('\n          ','')
        #help_margemliquida = help_tips[28].get_attribute_list('title')
        #Campo Oscilação 2019
        #field_oscilacao2019 = names[29].get_text()
        value_oscilacao2019 = data[29].get_text().replace('\n          ','')
        #help_oscilacao2019 = help_tips[29].get_attribute_list('title')
        #Campo P/ Capital de Giro
        #field_pcapitalgiro = names[30].get_text()
        value_pcapitalgiro = data[30].get_text().replace('\n          ','')
        #help_pcapitalgiro = help_tips[30].get_attribute_list('title')
        #Campo EBIT/Ativo
        #field_ebitativo = names[31].get_text()
        value_ebitativo = data[31].get_text().replace('\n          ','')
        #help_ebitativo = help_tips[31].get_attribute_list('title')
        #Campo Oscilação 2018
        #field_oscilacao2018 = names[32].get_text()
        value_oscilacao2018 = data[32].get_text().replace('\n          ','')
        #help_oscilacao2018 = help_tips[32].get_attribute_list('title')
        #Campo P/Ativ Circulante Líquido
        #field_pativcircliq = names[33].get_text()
        value_pativcircliq = data[33].get_text().replace('\n          ','')
        #help_pativcircliq = help_tips[33].get_attribute_list('title')
        #Campo ROIC
        #field_roic = names[34].get_text()
        value_roic = data[34].get_text().replace('\n          ','')
        #help_roic = help_tips[34].get_attribute_list('title')
        #Campo Oscilação 2017
        #field_oscilacao2017 = names[35].get_text()
        value_oscilacao2017 = data[35].get_text().replace('\n          ','')
        #help_oscilacao2017 = help_tips[35].get_attribute_list('title')
        #Campo Dividend Yield
        #field_divyield = names[36].get_text()
        value_divyield = data[36].get_text().replace('\n          ','')
        #help_divyield = help_tips[36].get_attribute_list('title')
        #Campo ROE
        #field_roe = names[37].get_text()
        value_roe = data[37].get_text().replace('\n          ','')
        #help_roe = help_tips[37].get_attribute_list('title')
        #Campo Oscilação 2016
        #field_oscilacao2016 = names[38].get_text()
        value_oscilacao2016 = data[38].get_text().replace('\n          ','')
        #help_oscilacao2016 = help_tips[38].get_attribute_list('title')
        #Campo EV/EBITDA
        #field_evebitda = names[39].get_text()
        value_evebitda = data[39].get_text().replace('\n          ','')
        #help_evebitda = help_tips[39].get_attribute_list('title')
        #Campo Liquidez Corrente
        #field_liquidezcorrente = names[40].get_text()
        value_liquidezcorrente = data[40].get_text().replace('\n          ','')
        #help_liquidezcorrente = help_tips[40].get_attribute_list('title')
        #Campo Oscilação 2015
        #field_oscilacao2015 = names[41].get_text()
        value_oscilacao2015 = data[41].get_text().replace('\n          ','')
        #help_oscilacao2015 = help_tips[41].get_attribute_list('title')
        #Campo EV/EBIT
        #field_evebit = names[42].get_text()
        value_evebit = data[42].get_text().replace('\n          ','')
        #help_evebit = help_tips[42].get_attribute_list('title')
        #Campo Divida Bruta / Patrimonio
        #field_divbrpatrim = names[43].get_text()
        value_divbrpatrim = data[43].get_text().replace('\n          ','')
        #help_divbrpatrim = help_tips[43].get_attribute_list('title')
        #Campo 44 não contém nada
        #Campo Crescimento Receita 5 anos
        #field_crescrec5a = names[45].get_text()
        value_crescrec5a = data[45].get_text().replace('\n          ','')
        #help_crescrec5a = help_tips[45].get_attribute_list('title')
        #Campo Giro Ativos
        #field_giroativos = names[46].get_text()
        value_giroativos = data[46].get_text().replace('\n          ','')
        #help_giroativos = help_tips[46].get_attribute_list('title')
        #Campo Ativo
        #field_ativo = names[47].get_text()
        value_ativo = data[47].get_text().replace('\n          ','')
        #help_ativo = help_tips[47].get_attribute_list('title')
        #Campo Dívida Bruta
        #field_divbruta = names[48].get_text()
        value_depositos = data[48].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Disponibilidades
        #field_disponibilidades = names[49].get_text()
        value_cartdecredito = data[49].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Dívida Líquida
        #field_divliquida = names[50].get_text()
        value_patrimliq = data[50].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Receita Líquida 12 meses
        #field_receitaliquida12m = names[53].get_text()
        value_receitaliquida12m = data[51].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Receita Líquida 3 meses
        #field_receitaliquida3m = names[54].get_text()
        value_receitaliquida3m = data[52].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo EBIT 12 meses
        #field_ebit12meses = names[55].get_text()
        value_ebit12meses = data[53].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo EBIT 3 meses
        #field_ebit3meses = names[56].get_text()
        value_ebit3meses = data[54].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Lucro Liquido 12 meses
        #field_lucroliquido12m = names[57].get_text()
        value_lucroliquido12m = data[55].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        #Campo Lucro Liquido 3 meses
        #field_lucroliquido3m = names[58].get_text()
        value_lucroliquido3m = data[56].get_text().replace('\n          ','')
        #help_divbruta = help_tips[48].get_attribute_list('title')
        
        # Campos preenchidos 

        value_disponibilidades = 0
        value_divliquida = 0
        value_ativocirculante = 0

        dict_data = {stock:[value_papel, value_cotacao, value_tipoacao, value_datacotacao, value_nomeempresa, value_min52sem, value_setor, value_max52sem, value_subsetor, value_volmedio2m, value_valormercado,value_ultimobalanco, value_valorfirma, value_numeroacoes, value_oscilacaodia, value_pl,value_pla,value_oscilacaomes, value_pvp, value_vpa, value_oscilacao30dias, value_pebit,value_margembruta, value_oscilacao12meses, value_psr,value_margemebit, value_oscilacao2020,value_pativos, value_margemliquida, value_oscilacao2019, value_pcapitalgiro, value_ebitativo,value_oscilacao2018, value_pativcircliq, value_roic, value_oscilacao2017, value_divyield,value_roe, value_oscilacao2016, value_evebitda, value_liquidezcorrente, value_oscilacao2015,value_evebit, value_divbrpatrim, value_crescrec5a, value_giroativos, value_ativo, value_depositos,value_cartdecredito, value_patrimliq, value_disponibilidades, value_divliquida, value_ativocirculante, value_receitaliquida12m, value_receitaliquida3m, value_ebit12meses, value_ebit3meses,value_lucroliquido12m, value_lucroliquido3m]
                    }

    else:
        print(len(data))
    
    #print(dict_data)
    

df = pd.DataFrame.from_dict(dict_data, orient='index', columns=['ACAO','VALOR_ULTIMA_COTACAO','TIPO_ACAO','DATA_ULTIMA_COTACAO','NOME_COMERCIAL_EMPRESA','MENOR_COTACAO_12M','SETOR_ATUACAO','MAIOR_COTACAO_52S','SUBSETOR','VOLUME_MEDIO_NEGOC_2M','VALOR_MERCADO','ULTIMO_BALANCO','VALOR_FIRMA','NUMERO_ACOES','OSCILACAO_DIA','P/L','LPA','OSCILACAO_MES','P/VP','VPA','OSCILACAO_30D','P/EBIT','MARGEM_BRUTA','OSCILACAO_12M','PSR','MARGEM_EBIT','OSCILACAO_2020','P/ATIVOS','MARGEM_LIQUIDA','OSCILACAO_2019','P/CAPITAL_GIRO','EBIT/ATIVO','OSCILACAO_2018','P/ATIVO_CIRC_LIQ','ROIC','OSCILACAO_2017','DIVIDEND_YIELD','ROE','OSCILACAO_2016','EV/EBITDA','LIQUIDEZ_CORRENTE','OSCILACAO_2015','EV/EBIT','DIVIDA_BRUTA/PATRIMONIO','CRESCIMENTO_RECEITA_5A','GIRO_ATIVOS','ATIVO','DEPOSITOS','CART_DE_CREDITO','PATRIMONIO_LIQUIDO','DISPONIBILIDADES','DIVIDA_LIQUIDA','ATIVO_CIRCULANTE','RECEITA_LIQUIDA_12M','RECEITA_LIQUIDA_3M','EBIT_12M','EBIT_3M','LUCRO_LIQUIDO_12M','LUCRO_LIQUIDO_3M'])
# Out:
# https://www.fundamentus.com.br/detalhes.php?papel=PINE4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5f57847a7474> in <module>
#     497         value_ativocirculante = 0
#     498
# ...

# %%
df.to_excel('fundamentus.xlsx', sheet_name='Base', index=False)
